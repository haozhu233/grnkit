# %%
import grnkit

# %%
aaa = grnkit.load_gse_70499()
# Out:
# Loading from processed file...

# %%
aaa.dd

# %%
import numpy as np

# %%
ccc = grnkit.BenchmarkData(np.zeros((10, 10)))

# %%
aaa.

# %%
import pickle

# %%
with open('sss', 'wb') as f:
    pickle.dump(aaa, f)

# %%
# Out:
# OverloadedDict, wrapping:
# ...

# %%
from pathlib import Path

HERE = Path('/Users/haozhu/Documents/grnkit/').parent

# %%
HERE / 'data' /'a'
# Out:
# PosixPath('/Users/haozhu/Documents/data/a')
